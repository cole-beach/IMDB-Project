# %% [markdown]
# # IMDB Business-Problem

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %% [markdown]
# # Loading Data

# %% [markdown]
# ## Basics Dataframe

# %%
basics_url = "https://datasets.imdbws.com/title.basics.tsv.gz"
basics = pd.read_csv(basics_url,sep='\t', low_memory=False)
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %% [markdown]
# ## Ratings Dataframe

# %%
ratings_url = "https://datasets.imdbws.com/title.ratings.tsv.gz"
ratings = pd.read_csv(ratings_url,sep='\t', low_memory=False)

# %% [markdown]
# ## AKAs Dataframe

# %%
akas_url = "https://datasets.imdbws.com/title.akas.tsv.gz"
akas = pd.read_csv(akas_url, sep='\t', low_memory=False)
akas.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA       \N
# 1  tt0000001         2                 Carmencita     DE       \N
# 2  tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3  tt0000001         4                 Καρμενσίτα     GR       \N
# 4  tt0000001         5                 Карменсита     RU       \N
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay             \N               0
# 1           \N  literal title               0
# 2  imdbDisplay             \N               0
# 3  imdbDisplay             \N               0
# 4  imdbDisplay             \N               0

# %%
akas.to_csv("Data/title_akas.csv.gz",compression='gzip',index=False)
akas = pd.read_csv("Data/title_akas.csv.gz", low_memory = False)
akas.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA       \N
# 1  tt0000001         2                 Carmencita     DE       \N
# 2  tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3  tt0000001         4                 Καρμενσίτα     GR       \N
# 4  tt0000001         5                 Карменсита     RU       \N
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay             \N               0
# 1           \N  literal title               0
# 2  imdbDisplay             \N               0
# 3  imdbDisplay             \N               0
# 4  imdbDisplay             \N               0

# %% [markdown]
# # Exploring Data

# %% [markdown]
# ## Missing Values

# %%
print(f'There are {basics.duplicated().sum()} duplicated values is the Basic Dataset\n')
print(f'There are {ratings.duplicated().sum()} duplicated values is the Ratings Dataset\n')
print(f'There are {akas.duplicated().sum()} duplicated values is the AKAs Dataset\n')
print(f'===========================================\n\n Basic Dataset Missing Values:\n')
# Basic Dataset Missing Values
basic_total = basics.isnull().sum().sort_values(ascending=False)
basic_percent = (basics.isnull().sum()/basics.isnull().count()).sort_values(ascending=False)
basic_missing_data = pd.concat([basic_total, basic_percent], axis=1, keys=['Total', 'Percentage'])
print(basic_missing_data)

print(f'===========================================\n\n Ratings Dataset Missing Values:\n')
# Ratings Dataset Missing Values
ratings_total = ratings.isnull().sum().sort_values(ascending=False)
ratings_percent = (ratings.isnull().sum()/ratings.isnull().count()).sort_values(ascending=False)
ratings_missing_data = pd.concat([ratings_total, ratings_percent], axis=1, keys=['Total', 'Percentage'])
print(ratings_missing_data)

print(f'===========================================\n\n AKAs Dataset Missing Values:\n')
# AKAs Dataset Missing Values
akas_total = akas.isnull().sum().sort_values(ascending=False)
akas_percent = (akas.isnull().sum()/akas.isnull().count()).sort_values(ascending=False)
akas_missing_data = pd.concat([akas_total, akas_percent], axis=1, keys=['Total', 'Percentage'])
print(akas_missing_data)
# Out:
# There are 0 duplicated values is the Basic Dataset
#
# There are 0 duplicated values is the Ratings Dataset
#
# There are 0 duplicated values is the AKAs Dataset
#
# ===========================================
#
#  Basic Dataset Missing Values:
#
#                 Total  Percentage
# primaryTitle       11    0.000001
# originalTitle      11    0.000001
# genres             10    0.000001
# tconst              0    0.000000
# titleType           0    0.000000
# isAdult             0    0.000000
# startYear           0    0.000000
# endYear             0    0.000000
# runtimeMinutes      0    0.000000
# ===========================================
#
#  Ratings Dataset Missing Values:
#
#                Total  Percentage
# tconst             0         0.0
# averageRating      0         0.0
# numVotes           0         0.0
# ===========================================
#
#  AKAs Dataset Missing Values:
#
#                  Total    Percentage
# region             103  3.159215e-06
# title                5  1.533600e-07
# titleId              0  0.000000e+00
# ordering             0  0.000000e+00
# language             0  0.000000e+00
# types                0  0.000000e+00
# attributes           0  0.000000e+00
# isOriginalTitle      0  0.000000e+00

# %% [markdown]
# ### Exploring Basics Missing Values

# %%
basics.replace({'\\N':np.nan}, inplace=True)
clean_basics = basics.dropna(inplace=True)

# %% [markdown]
# ### Exploring AKAs Missing Values

# %%
akas.replace({'\\N':np.nan}, inplace=True)
clean_akas = akas.dropna(inplace=True)

# %% [markdown]
# ## Filtering

# %%
# Exclude movies that are included in the documentary category.
is_documentary = basics['genres'].str.contains('documentary',case=False)
basics = basics[~is_documentary]

# %%
# Filter the basics table down to only include the US by using the filter akas dataframe
keepers = basics['tconst'].isin(akas['titleId'])
keepers
# Out:
# 25060      False
# 37589      False
# 38423      False
# 38424      False
# 38426      False
#            ...
# 9086358    False
# 9086391    False
# 9086492    False
# 9086698    False
# 9086878    False
# Name: tconst, Length: 37662, dtype: bool

# %%
basics = basics[keepers]
basics
# Out:
#             tconst titleType               primaryTitle  \
# 45577    tt0046415  tvSeries  The Count of Monte Cristo
# 69499    tt0071010  tvSeries              The Manhunter
# 2543361  tt1286039  tvSeries          Stargate Universe
# 4710451  tt1772752  tvSeries                A.N.T. Farm
# 4794041  tt1826071  tvSeries        Adini Feriha Koydum
# 5576072  tt2224968  tvSeries          Jang Geum's Dream
# 6268231  tt3672132  tvSeries               Anali Ogullu
# 6801492  tt4875520  tvSeries     Iliski Durumu: Karisik
# 8349591  tt8315348  tvSeries                       4N1K
# 8384082  tt8390060  tvSeries     Her sey yolunda merkez
# 8971243  tt9667744  tvSeries                   Yüzlesme
#
#                     originalTitle isAdult startYear endYear runtimeMinutes  \
# 45577    Le comte de Monte-Cristo       0      1954    1954            183
# 69499               The Manhunter       0      1974    1975             60
# 2543361    SG.U Stargate Universe       0      2009    2011             43
# 4710451               A.N.T. Farm       0      2011    2014             30
# 4794041       Adini Feriha Koydum       0      2011    2012            120
# 5576072       Jang Geum ieui Kkum       0      2005    2007             30
# 6268231              Anali Ogullu       0      2014    2014             80
# 6801492    Iliski Durumu: Karisik       0      2015    2016            120
# 8349591                      4N1K       0      2018    2019            100
# 8384082    Her sey yolunda merkez       0      2013    2013             90
# 8971243                  Yüzlesme       0      2019    2019            120
#
#                              genres
# 45577       Adventure,Drama,Romance
# 69499                         Drama
# 2543361                Drama,Sci-Fi
# 4710451         Comedy,Drama,Family
# 4794041               Drama,Romance
# 5576072  Adventure,Animation,Comedy
# 6268231                      Comedy
# 6801492              Comedy,Romance
# 8349591              Comedy,Romance
# 8384082                      Comedy
# 8971243                       Drama

# %% [markdown]
# # Saving Compressed Files

# %%
basics.to_csv("Data/title_basics.csv.gz",compression='gzip',index=False)
basics = pd.read_csv("Data/title_basics.csv.gz", low_memory = False)
basics.head()
# Out:
#       tconst titleType               primaryTitle             originalTitle  \
# 0  tt0046415  tvSeries  The Count of Monte Cristo  Le comte de Monte-Cristo
# 1  tt0071010  tvSeries              The Manhunter             The Manhunter
# 2  tt1286039  tvSeries          Stargate Universe    SG.U Stargate Universe
# 3  tt1772752  tvSeries                A.N.T. Farm               A.N.T. Farm
# 4  tt1826071  tvSeries        Adini Feriha Koydum       Adini Feriha Koydum
#
#    isAdult  startYear  endYear  runtimeMinutes                   genres
# 0        0       1954     1954             183  Adventure,Drama,Romance
# 1        0       1974     1975              60                    Drama
# 2        0       2009     2011              43             Drama,Sci-Fi
# 3        0       2011     2014              30      Comedy,Drama,Family
# 4        0       2011     2012             120            Drama,Romance

# %%
ratings.to_csv("Data/title_ratings.csv.gz",compression='gzip',index=False)
ratings = pd.read_csv("Data/title_ratings.csv.gz", low_memory = False)
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1898
# 1  tt0000002            5.9       254
# 2  tt0000003            6.5      1692
# 3  tt0000004            5.7       166
# 4  tt0000005            6.2      2508

# %%
akas.to_csv("Data/title_akas.csv.gz",compression='gzip',index=False)
akas = pd.read_csv("Data/title_akas.csv.gz", low_memory = False)
akas.head()
# Out:
#      titleId  ordering                    title region language        types  \
# 0  tt0022542         1    Di shtime fun Yisroel     US       yi  alternative
# 1  tt0024265         4         Geleb un gelakht     US       yi  alternative
# 2  tt0024751         9              Avram Ovenu     US       yi  alternative
# 3  tt0026010         3  Der yidishe Kenigen Lir     US       yi  alternative
# 4  tt0027911         1       Libe un Laydnshaft     US       yi  alternative
#
#            attributes  isOriginalTitle
# 0    YIVO translation                0
# 1  modern translation                0
# 2    YIVO translation                0
# 3    YIVO translation                0
# 4  modern translation                0
